# %%
import pandas as pd

# %%
df2 = pd.read_csv("DS_Prueba.csv", index_col = 0)
df2
# Out:
#            y^2
# x^2
# 13.98   209.70
# 5.80    185.60
# 27.64    82.92
# 10.06   160.96
# 5.92    272.32
# ...        ...
# 27.83    61.50
# 55.50   105.45
# 19.46    48.46
# 900.00  900.00
# 436.00  436.00
#
# [5000 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(X, y, "g.")
plt.show()
